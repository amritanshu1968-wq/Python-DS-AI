# %%
name = "Amritanshu Shukla"

age = 21

Height = 5.11

in_student = True

print(name,age,Height,in_student)

print(type(name))
print(type(age))
print(type(Height))
print(type(in_student))
# Out:
# Amritanshu Shukla 21 5.11 True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
x = "100"
y = int(x)
z = float(x)
s = str(x)
print(y, type(y))
print(z, type(z))
# Out:
# 100 <class 'int'>
# 100.0 <class 'float'>

# %%
text = "python is a Programming language"

print(text.upper()) #PYTHON PROGRAMMING LANGUAGE

print(text.lower()) #python programming language

print(text.replace("python", "java")) #java is a Programming language

print(text.split()) #['python', 'is', 'a', 'Programming', 'language']

print(len(text)) #32
# Out:
# PYTHON IS A PROGRAMMING LANGUAGE
# python is a programming language
# java is a Programming language
# ['python', 'is', 'a', 'Programming', 'language']
# 32

# %%
fruits = ["apple", "banana", "cherry", "date"]

cord = (10, 20, 30, 40)

student = {"name": "Amritanshu", "age": 21, "course": "Python"}

unique_name = {1, 2, 3, 4, 5}

fruits.append("elderberry")

print(fruits) #['apple', 'banana', 'cherry', 'date', 'elderberry']

print(cord)

print(student["name"]) #Amritanshu

print(unique_name) #{1, 2, 3, 4, 5}
# Out:
# ['apple', 'banana', 'cherry', 'date', 'elderberry']
# (10, 20, 30, 40)
# Amritanshu
# {1, 2, 3, 4, 5}

# %%
#create a variable for your favourite movie title(str), release year(int), rating out of 10
#recommend it bool(true/false) print each type

# Create variables
movie_title = "3 Idiots"      # String
release_year = 2009           # Integer
rating = 9.5                  # Float
recommend = True              # Boolean

# Print values
print("Movie Title:", movie_title)
print("Release Year:", release_year)
print("Rating:", rating)
print("Recommend:", recommend)

# Print data types
print("\nData Types:")
print(type(movie_title))
print(type(release_year))
print(type(rating))
print(type(recommend))
# Out:
# Movie Title: 3 Idiots
# Release Year: 2009
# Rating: 9.5
# Recommend: True
#
# Data Types:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#Create a dictionary representing a product with keys
#name,price,and tags (a list). write code to dd a new tag,
#update the price by applying a 10% discount, and print a formatted sentence
#describing the final product using an f-string.

# Create a dictionary representing a product
product = {
    "name": "Laptop",
    "price": 50000,
    "tags": ["Electronics", "Portable"]
}

# Add a new tag
product["tags"].append("Discounted")

# Apply a 10% discount
product["price"] = product["price"] * 0.9  # 10% discount

# Print the final product details using an f-string
print(f"The product '{product['name']}' now costs ₹{product['price']:.2f} and belongs to the categories: {', '.join(product['tags'])}.")
# Out:
# The product 'Laptop' now costs ₹45000.00 and belongs to the categories: Electronics, Portable, Discounted.

# %%
#Bitwise Operators

#bitwise operators demo
a = 5  # binary: 0101
b = 3  # binary: 0011
print("AND =", a & b)
print("OR =", a | b)
print("XOR =", a ^ b)
print("NOT =", ~a)
print("Left Shift =", a << 1)
print("Right Shift =", a >> 1)

#mixed Expression
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
result = (a + b) * c - a / b
print("Result =", result)
# Out:
# AND = 1
# OR = 7
# XOR = 6
# NOT = -6
# Left Shift = 10
# Right Shift = 2
# Enter first number: 25
# Enter second number: 36
# Enter third number: 56
# Result = 3415.3055555555557

# %%
#Assignment Operators
#Assignment operators Demo

a = 10

a += 5
print("After += :", a)

a -= 3
print("After -= :", a)

a *= 2
print("After *= :", a)

a /= 4
print("After /= :", a)

a %= 3
print("After %= :", a)
# Out:
# After += : 15
# After -= : 12
# After *= : 24
# After /= : 6.0
# After %= : 0.0

# %%
#given two numbers entered by user, write expression to print their sum, difference
#product quotient, floor division, remainder, and the first number raised to the power of the second number.
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Sum =", num1 + num2)
print("Difference =", num1 - num2)
print("Product =", num1 * num2)
print("Quotient =", num1 / num2)
print("Floor Division =", num1 // num2)
print("Remainder =", num1 % num2)
print("Power =", num1 ** num2)
# Out:
# Enter first number: 12
# Enter second number: 11
# Sum = 23.0
# Difference = 1.0
# Product = 132.0
# Quotient = 1.0909090909090908
# Floor Division = 1.0
# Remainder = 1.0
# Power = 743008370688.0

# %%
#Membership Operators
#Check character in a string
Text = input("Enter a string: ")
char = input("Enter a character to check: ")
if char in Text:
    print(char, "is present in the string.")
else:
    print(char, "is not present in the string.")

#Check number in a list
numbers = [1, 2, 3, 4, 5]
num = int(input("Enter a number to check: "))
if num in numbers:
    print(num, "is present in the list.")
else:
    print(num, "is not present in the list.")

#Identity Operators

#Identity operator
a = [10, 20, 30]
b = a
c = [10, 20, 30]
print(a is b)  # True, because b references the same object as a
print(a is c)  # False, because c is a different object with the same content
print(a is not c)  # True, because a and c are different objects
# Out:
# Enter a string: i am good
# Enter a character to check: am
# am is present in the string.
# Enter a number to check: 56
# 56 is not present in the list.
# True
# False
# True

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are an adult")
else:
    print("You are not an adult")
# Out:
# Enter your age: 25
# You are an adult
